# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv('Monthly_expenditure.csv')
dataset
# Out:
#     Age  Annual Income (USD)  Family Members  Monthly Expenditure (USD)
# 0    56                87563               6                4042.661813
# 1    46                22695               8                2586.985961
# 2    32                68190               5                3033.931809
# 3    60                25258               4                2502.017012
# 4    25                59504               2                1824.065187
# ..  ...                  ...             ...                        ...
# 95   42                83734               3                3160.474086
# 96   24                90467               1                2421.462741
# 97   26                72662               5                2810.185813
# 98   41                32688               2                2013.578476
# 99   18                45342               8                2986.819327
#
# [100 rows x 4 columns]

# %%
dataset.shape
# Out:
# (100, 4)

# %%
dataset.describe()
# Out:
#               Age  Annual Income (USD)  Family Members  \
# count  100.000000           100.000000       100.00000
# mean    40.920000         60547.060000         4.53000
# std     14.054497         23168.998111         2.49628
# min     18.000000         20206.000000         1.00000
# 25%     30.500000         42218.250000         3.00000
# 50%     41.000000         63263.000000         4.00000
# 75%     53.250000         81494.250000         7.00000
# max     65.000000         99575.000000         8.00000
#
#        Monthly Expenditure (USD)
# count                 100.000000
# mean                 2922.896004
# std                   675.486682
# min                  1249.465366
# 25%                  2436.074679
# 50%                  2930.400930
# 75%                  3420.465868
# max                  4241.904882

# %%
x = dataset.iloc[:,:-1].values 
y = dataset.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test = sc.transform(x_test)
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_pred,y_test)

# %%
print(mse)
# Out:
# 859501741377592.2
